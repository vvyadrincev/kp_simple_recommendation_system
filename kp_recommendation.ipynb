# %%
from tqdm import tqdm_notebook as tqdm
import json
import datetime
import re
import os
import json
import requests
import math
import collections
import pandas as pd
import numpy as np
import scipy.sparse as sp

np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
base_dir = 'kp_data'
sample_subdir = 'sample'

user2vote_csr_file = os.path.join(base_dir, sample_subdir, "user2vote.npz")
users_file         = os.path.join(base_dir, sample_subdir, "users.csv")
movies_file        = os.path.join(base_dir, sample_subdir, "movies.csv")

# %% [markdown]
# ## Load sample

# %%
def load_int2int_dict(filename):
    with open(os.path.join(base_dir, sample_subdir, filename), 'r') as f:
        j = json.load(f)
        return {int(i): int(j[i]) for i in j}

def load_sample():
    user2vote_csr = sp.load_npz(user2vote_csr_file)
    users  = pd.read_csv(users_file, index_col=0)
    movies = pd.read_csv(movies_file, index_col=0)
    movie_id2id = load_int2int_dict('movie_id2id.json')
    id2movie_id = load_int2int_dict('id2movie_id.json')
    id2user_id = load_int2int_dict('id2user_id.json')
    user_id2id = load_int2int_dict('user_id2id.json')
    
    assert (max(id2movie_id.keys()) == len(id2movie_id) - 1)
    assert (len(movie_id2id) == len(id2movie_id))
    print ("len(id2movie_id)", len(id2movie_id))
           
    assert (max(id2user_id.keys()) == len(id2user_id) - 1)
    assert (len(user_id2id) == len(id2user_id))
    print ("len(id2user_id)", len(id2user_id))
           
    print ('user2vote_csr.shape', user2vote_csr.shape)
    
    return user2vote_csr, users, movies, movie_id2id, id2movie_id, user_id2id, id2user_id

# %%
# %%time 

user2vote_csr, users, movies, movie_id2id, id2movie_id, user_id2id, id2user_id = load_sample()
# Out:
# len(id2movie_id) 13776
# len(id2user_id) 218007
# user2vote_csr.shape (218007, 13776)
# Wall time: 3 s

# %%
# movies[movies['id']==4873]

# %%
# id2movie_id[0] == 12252

# %%
# movie_id2id[4873] == 1

# %%
movies
# Out:
#             id                                             href  \
# 5        12252                          /film/skiny-1992-12252/
# 6         4873                                      /film/4873/
# 7       678269                                    /film/678269/
# 9         4743                                      /film/4743/
# 11      161180                        /film/pevets-2006-161180/
# 15       86964                             /film/ad-2005-86964/
# 17      477855                                    /film/477855/
# 20      974817                                    /film/974817/
# 21      277328                      /film/varkraft-2016-277328/
# 24      596231                                    /film/596231/
# 25       79836              /film/tokiyskaya-povest-1953-79836/
# 27      102787                                    /film/102787/
# 28      237940                       /film/skeptik-2007-237940/
# 30      195429                                    /film/195429/
# 31      482078                    /film/razdelitel-2011-482078/
# 32      713798                        /film/iz-tmy-2015-713798/
# 36        9980                     /film/voyna-i-mir-1956-9980/
# 37         621                                       /film/621/
# 41        4311                                      /film/4311/
# 45        3607                                      /film/3607/
# 46      901796     /film/v-poiske-film-proshchanie-2016-901796/
# 52      677880                       /film/va-bank-2013-677880/
# 53        5610                 /film/idushhiy-v-ogne-1986-5610/
# 57        6899                                      /film/6899/
# 59       78079                                     /film/78079/
# 64      487226     /film/posledniy-mamont-frantsii-2010-487226/
# 69      970085                                    /film/970085/
# 71       11617                                     /film/11617/
# 76           100                           триллер,ужасы,фантастика
# ...          ...                                                ...
# 115243        87                                            комедия
# 115397        97                            криминал,документальный
# 115941       101                   история,семейный,драма,мелодрама
# 117018       135                                              драма
# 117132       155                                      комедия,драма
# 117890        77                                            комедия
# 117910       102                                      драма,комедия
# 118305        99                                              драма
# 118426       169                  мелодрама,детектив,мюзикл,комедия
# 118897       118                                              драма
# 119605        94                     драма,биография,документальный
# 120056       130                                              драма
# 120595        85                           биография,документальный
# 121329        95                                            комедия
# 122129       116                                    драма,мелодрама
# 123088       108            триллер,детектив,комедия,драма,криминал
# 123998        84                                     документальный
# 124980       106                                   криминал,комедия
# 125533        90                                  мелодрама,комедия
# 128332       111                               мюзикл,комедия,спорт
# 128872       109                              драма,военный,комедия
# 131358       101                 вестерн,документальный,приключения
# 131520       138                              музыка,документальный
# 132924        94                                     документальный
# 133398        96                               документальный,спорт
# 133644        90                                              драма
# 135587        88                          документальный,мультфильм
# 141705        82                                     документальный
# 143947       112    приключения,комедия,семейный,фэнтези,мультфильм
# 202239       128      триллер,приключения,боевик,фэнтези,фантастика
#
#                                          countries
# 5                                        Австралия
# 6                                              США
# 7                                              США
# 9                       Великобритания,США,Австрия
# 11                                             США
# 15                   Италия,Франция,Бельгия,Япония
# 17                                             США
# 20                                             США
# 21                         Китай,США,Канада,Япония
# 24                     Болгария,США,Канада,Испания
# 25                                          Япония
# 27                                      США,Италия
# 28                                             США
# 30                        Великобритания,Австралия
# 31                     США,Канада,Франция,Германия
# 32                     Великобритания,США,Ирландия
# 36                                      США,Италия
# 37                      Великобритания,США,Франция
# 41                                             США
# 45                       США,Великобритания,Италия
# 46                                             США
# 52                                             США
# 53                                             США
# 57                                             США
# 59      Великобритания,Нидерланды,Бельгия,Германия
# 64                                         Франция
# 69                                             США
# 71                                  Италия,Франция
# 72                                             США
# 76                                      Россия,США
# ...                                            ...
# 115243                                         США
# 115397                     Ирландия,Великобритания
# 115941                                         США
# 117018                                         США
# 117132                                       Индия
# 117890                                         США
# 117910                              Великобритания
# 118305                                      Япония
# 118426                           Франция,Швейцария
# 118897                                         США
# 119605                              Великобритания
# 120056                          Великобритания,США
# 120595                                         США
# 121329                                         США
# 122129            Китай,Франция,Нидерланды,Гонконг
# 123088                                         США
# 123998                                         США
# 124980                          Великобритания,США
# 125533                                         США
# 128332                                         США
# 128872                          Люксембург,Австрия
# 131358                  Франция,Великобритания,США
# 131520                          Великобритания,США
# 132924                                         США
# 133398                                         США
# 133644                                         США
# 135587                                     Франция
# 141705              Франция,Швейцария,Чили,Испания
# 143947                                         США
# 202239                          США,Новая Зеландия
#
# [13776 rows x 13 columns]

# %%
user2vote_csr
# Out:
# <218007x13776 sparse matrix of type '<class 'numpy.float64'>'
# 	with 33582215 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Recommendation algorithms got from https://geekbrains.ru/events/657

# %% [markdown]
# #### Recommendation functions

# %%
def get_id2value(row):
#     if not row.has_sorted_indices:
#         row = row.sorted_indices()

    return {int(indice): int(row.data[i]) 
            for i, indice in enumerate(row.indices)}

def sim_pearson (prefs_csr, person1, person2, 
                            person1_i2v = None, 
                            person2_i2v = None,
                            count_thres = 1,
                            votes_thres = 0.8):
    if person1_i2v is None:
        person1_i2v = get_id2value(prefs_csr[person1])
    if person2_i2v is None:
        person2_i2v = get_id2value(prefs_csr[person2])

    si = person1_i2v.keys() & person2_i2v.keys()
    
    if len(si) < count_thres or len(si) < len(person1_i2v.keys())*votes_thres :
        return 0.0

    corr = np.corrcoef([person1_i2v[i] for i in si],
                       [person2_i2v[i] for i in si])[0,1]

    if math.isnan(corr):
        return 0.0

    return corr

def top_matches(prefs_csr, person, n = 5, similarity = sim_pearson):
    scores = []
    found_absoulete_correlation = 0
    for other, _ in enumerate(prefs_csr):
                              
        if other == person:
            continue
                              
        rate = similarity(prefs_csr, person, other)
        if rate == 1.0:
            found_absoulete_correlation += 1
        
        scores.append((rate, other))
        
        if found_absoulete_correlation == n:
            break

    scores.sort()
    scores.reverse()
    return scores[:n]

def get_reccomentations(prefs_csr, person = -1, similarity = sim_pearson, 
                        n = 5, person_mid2vote = None, votes_count_thres = 10):
    totals    = {} # {mid: sum [sim(i) * rate(i)]}
    sim_sums  = {} # {mid: sum [sim(i)] }
    counter   = collections.Counter()
    for other, _ in enumerate(prefs_csr):
        if other == person: continue
            
        person1_i2v = get_id2value(prefs_csr[person]) if person_mid2vote is None else person_mid2vote
        person2_i2v = get_id2value(prefs_csr[other])
        sim = similarity(prefs_csr, person, other, person1_i2v, person2_i2v)
        
        if sim <= 0.1: continue 

        for item in person2_i2v.keys():
            if item not in person1_i2v.keys(): # did not watched yet
                totals.setdefault(item, 0.0)
                totals[item] += sim * person2_i2v[item]
                
                sim_sums.setdefault(item, 0.0)
                sim_sums[item] += sim 
                
                counter[item] += 1

    rank = [(totals[item]/sim_sums[item], item)
             for item in totals.keys()
             if item in sim_sums.keys() and counter[item] > votes_count_thres]
        
    rank.sort()
    rank.reverse()
    return rank[:n]

def get_movie_descr_by_id(mid, fields = ('name_rus', 'name_eng', 'year', 'rating', 'genres', 'countries')):
    m = movies.loc[movies['id'] == id2movie_id[mid]]
    return [m[f].tolist()[0] for f in fields]
def get_user_descr_by_id(uid, fields = ('user_id', 'nickname', 'gender', 'country', 'city', 'birth_date')):
    u = users.loc[users['user_id'] == id2user_id[uid]]
    return [u[f].tolist()[0] for f in fields]

def get_filmid2vote(votes):
    _filmid2vote = {
        int(href.split('/')[-2].split('-')[-1]): votes[href]['vote']
        for href in votes
    }

    _filmid2vote = {movie_id2id[movie_id]: vote 
                    for movie_id, vote in _filmid2vote.items()
                    if movie_id in movie_id2id}
    return _filmid2vote

# %%
# movies.loc[(movies['name_rus'] == 'Профессионал') & (movies['year'] == 2018)]['id']

# %%
# get_movie_descr_by_id(movie_id2id[1038843])

# %% [markdown]
# ## Recommend!
# ## Работает достаточно долго!

# %%
from kp_utils import *

# real users
user_1 = 15666129
user_2 = 1979843
user_3 = 15425314

# establishing session
s = requests.Session()
s.headers.update({
        'Referer': 'http://www.kinopoisk.ru',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36',
        'Host': "www.kinopoisk.ru",
        'Upgrade-Insecure-Requests': '1',
        'Cookie': "mobile=no; noflash=true; hideBlocks=0; my_perpages=%7B%2277%22%3A200%2C%2279votes%22%3A200%7D",
        'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,de;q=0.6',
        'Referer' : 'https://www.kinopoisk.ru',
        'Accept'  : "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
        'Connection': 'keep-alive'    
    })

# %%
# %%time
votes_1 = get_user_votes_for_films(user_i=user_1, session=s)
# Out:
# Wall time: 1.41 s

# %%
# %%time
votes_2 = get_user_votes_for_films(user_i=user_2, session=s)
# Out:
# Wall time: 785 ms

# %%
# %%time
votes_3 = get_user_votes_for_films(user_i=user_3, session=s)
# Out:
# Wall time: 2.01 s

# %%
for mid, vote in get_filmid2vote(votes_1).items():
    print (vote, get_movie_descr_by_id(mid))
# Out:
# 9 ['Жизнь Пи', 'Life of Pi', 2012, 7.822999999999999, 'драма,приключения,фэнтези', 'Великобритания,Канада,Тайвань,США']
# 9 ['Эффект бабочки', 'The Butterfly Effect', 2003, 8.169, 'фантастика,триллер', 'США,Канада']
# 10 ['Прислуга', 'The Help', 2011, 8.162, 'драма', 'ОАЭ,Индия,США']
# 8 ['Шрек', 'Shrek', 2001, 7.978, 'семейный,фэнтези,приключения,мультфильм,комедия', 'США']
# 8 ['Назад в будущее\xa03', 'Back to the Future Part III', 1990, 8.169, 'приключения,фантастика,вестерн,комедия', 'США']
# 8 ['Терминал', 'The Terminal', 2004, 8.068, 'драма,мелодрама,комедия', 'США']
# 10 ['Перл-Харбор', 'Pearl Harbor', 2001, 7.923999999999999, 'история,военный,боевик,драма,мелодрама', 'США']
# 7 ['В поисках Немо', 'Finding Nemo', 2003, 7.862999999999999, 'семейный,фэнтези,приключения,мультфильм,комедия', 'США']
# 8 ['Великий Гэтсби', 'The Great Gatsby', 2013, 7.94, 'драма,мелодрама', 'Австралия,США']
# 9 ['Бесславные ублюдки', 'Inglourious Basterds', 2009, 7.867000000000001, 'боевик,драма,военный,комедия', 'Германия,США']
# 9 ['Один дома', 'Home Alone', 1990, 8.232000000000001, 'семейный,комедия', 'США']
# 8 ['День сурка', 'Groundhog Day', 1993, 8.103, 'мелодрама,фэнтези,комедия', 'США']
# 9 ['Назад в будущее\xa02', 'Back to the Future Part II', 1989, 8.287, 'семейный,боевик,фантастика,приключения,комедия', 'США']
# 8 ['Зверополис', 'Zootopia', 2016, 8.302999999999999, 'семейный,приключения,мультфильм,детектив,криминал,комедия', 'США']
# 8 ['Джанго освобожденный', 'Django Unchained', 2012, 8.177, 'драма,приключения,вестерн,комедия', 'США']
# 9 ['Шоу Трумана', 'The Truman Show', 1998, 8.254, 'драма,фантастика,комедия', 'США']
# 8 ['Запах женщины', 'Scent of a Woman', 1992, 8.458, 'драма', 'США']
# 9 ['Титаник', 'Titanic', 1997, 8.369, 'драма,мелодрама', 'США']
# 8 ['Пираты Карибского моря: Проклятие Черной жемчужины', 'Pirates of the Caribbean: The Curse of the Black Pearl', 2003, 8.337, 'боевик,приключения,фэнтези', 'США']
# 9 ['Властелин колец: Две крепости', 'The Lord of the Rings: The Two Towers', 2002, 8.559, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 9 ['Большой куш', 'Snatch.', 2000, 8.532, 'боевик,криминал,комедия', 'Великобритания,США']
# 9 ['Властелин колец: Братство кольца', 'The Lord of the Rings: The Fellowship of the Ring', 2001, 8.562000000000001, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 10 ['Пианист', 'The Pianist', 2002, 8.471, 'драма,музыка,биография,военный', 'Франция,Германия,Польша,Великобритания']
# 8 ['Отступники', 'The Departed', 2006, 8.456, 'драма,криминал,триллер', 'Гонконг,США']
# 9 ['Поймай меня, если сможешь', 'Catch Me If You Can', 2002, 8.514, 'драма,биография,криминал', 'Канада,США']
# 9 ['Матрица', 'The Matrix', 1999, 8.491, 'боевик,фантастика', 'США']
# 10 ['Карты, деньги, два ствола', 'Lock, Stock and Two Smoking Barrels', 1998, 8.544, 'криминал,комедия', 'Великобритания']
# 10 ['Назад в будущее', 'Back to the Future', 1985, 8.625, 'приключения,фантастика,комедия', 'США']
# 9 ['Властелин колец: Возвращение Короля', 'The Lord of the Rings: The Return of the King', 2003, 8.615, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 9 ['Престиж', 'The Prestige', 2006, 8.525, 'драма,детектив,фантастика,триллер', 'Великобритания,США']
# 9 ['Леон', 'Léon', 1994, 8.682, 'драма,криминал,триллер', 'Франция']
# 9 ['Король Лев', 'The Lion King', 1994, 8.773, 'семейный,драма,мюзикл,приключения,мультфильм', 'США']
# 9 ['Начало', 'Inception', 2010, 8.665, 'боевик,драма,фантастика,детектив,триллер', 'Великобритания,США']
# 10 ['Хатико: Самый верный друг', "Hachi: A Dog's Tale", 2008, 8.343, 'драма,семейный', 'Великобритания,США']
# 3 ['Профессионал', 'Siberia', 2018, 3.925, 'криминал,мелодрама,триллер', 'США']
# 8 ['Бойцовский клуб', 'Fight Club', 1999, 8.65, 'драма,криминал,триллер', 'Германия,США']
# 10 ['Интерстеллар', 'Interstellar', 2014, 8.586, 'драма,приключения,фантастика', 'Великобритания,США']
# 10 ['1+1', 'Intouchables', 2011, 8.809, 'драма,биография,комедия', 'Франция']
# 10 ['Список Шиндлера', "Schindler's List", 1993, 8.818999999999997, 'драма,биография,история', 'США']
# 10 ['Зеленая миля', 'The Green Mile', 1999, 9.062, 'драма,детектив,криминал,фэнтези', 'США']
# 10 ['Побег из Шоушенка', 'The Shawshank Redemption', 1994, 9.112, 'драма', 'США']

# %%
for mid, vote in get_filmid2vote(votes_2).items():
    print (vote, get_movie_descr_by_id(mid))
# Out:
# 4 ['Девушка в поезде', 'The Girl on the Train', 2016, 6.541, 'драма,детектив,криминал,триллер', 'США']
# 9 ['Фантастические твари и где они обитают', 'Fantastic Beasts and Where to Find Them', 2016, 7.56, 'приключения,семейный,фэнтези', 'Великобритания,США']
# 8 ['Как приручить дракона\xa02', 'How to Train Your Dragon\xa02', 2014, 7.923999999999999, 'семейный,фэнтези,приключения,мультфильм,комедия', 'США']
# 8 ['Город героев', 'Big Hero\xa06', 2014, 7.9289999999999985, 'семейный,боевик,фантастика,мультфильм,комедия', 'США']
# 5 ['Интерстеллар', 'Interstellar', 2014, 8.586, 'драма,приключения,фантастика', 'Великобритания,США']
# 8 ['Одержимость', 'Whiplash', 2013, 8.324, 'драма,музыка', 'США']
# 10 ['Мальчик в полосатой пижаме', 'The Boy in the Striped Pyjamas', 2008, 8.174, 'драма,военный', 'Великобритания,США']

# %%
for mid, vote in get_filmid2vote(votes_3).items():
    print (vote, get_movie_descr_by_id(mid))
# Out:
# 9 ['Ла-Ла Ленд', 'La La Land', 2016, 7.904, 'музыка,драма,мелодрама,мюзикл,комедия', 'Гонконг,США']
# 8 ['Безумный Макс: Дорога ярости', 'Mad Max: Fury Road', 2015, 7.814, 'боевик,приключения,фантастика', 'Австралия,США']
# 8 ['Тачки\xa03', 'Cars\xa03', 2017, 7.102, 'семейный,спорт,приключения,мультфильм,комедия', 'США']
# 7 ['Стартрек: Бесконечность', 'Star Trek: Beyond', 2016, 6.857, 'боевик,приключения,фантастика,триллер', 'Гонконг,США,Китай']
# 9 ['Темный рыцарь', 'The Dark Knight', 2008, 8.505, 'триллер,боевик,драма,фантастика,криминал', 'Великобритания,США']
# 8 ['Титаник', 'Titanic', 1997, 8.369, 'драма,мелодрама', 'США']
# 8 ['Мстители: Война бесконечности', 'Avengers: Infinity War', 2018, 7.892, 'боевик,приключения,фантастика,фэнтези', 'США']
# 8 ['Чёрная Пантера', 'Black Panther', 2018, 6.54, 'боевик,приключения,фантастика', 'Корея Южная,ЮАР,Австралия,США']
# 9 ['Аватар', 'Avatar', 2009, 7.944, 'боевик,драма,приключения,фантастика', 'Великобритания,США']
# 7 ['Звёздные войны: Пробуждение силы', 'Star Wars: Episode VII - The Force Awakens', 2015, 7.112, 'боевик,приключения,фантастика,фэнтези', 'США']
# 8 ['Зеленая миля', 'The Green Mile', 1999, 9.062, 'драма,детектив,криминал,фэнтези', 'США']
# 9 ['Побег из Шоушенка', 'The Shawshank Redemption', 1994, 9.112, 'драма', 'США']
# 9 ['Веном', 'Venom', 2018, 6.996, 'боевик,ужасы,фантастика,триллер', 'США,Китай']

# %%
# %%time

for rate, mid in get_reccomentations(user2vote_csr, n = 20, person_mid2vote=get_filmid2vote(votes_1), votes_count_thres = 100):
    print (round(rate, 2), get_movie_descr_by_id(mid))
# Out:
# 9.31 ['Форрест Гамп', 'Forrest Gump', 1994, 8.916, 'драма,мелодрама', 'США']
# 8.8 ['Игры разума', 'A Beautiful Mind', 2001, 8.558, 'драма,биография,мелодрама', 'США']
# 8.8 ['Гладиатор', 'Gladiator', 2000, 8.587, 'боевик,драма,приключения', 'Великобритания,США']
# 8.78 ['Жизнь прекрасна', 'La vita è bella', 1997, 8.628, 'драма,военный,комедия', 'Италия']
# 8.76 ['Крестный отец', 'The Godfather', 1972, 8.735, 'драма,криминал', 'США']
# 8.73 ['Криминальное чтиво', 'Pulp Fiction', 1994, 8.62, 'криминал,триллер,комедия', 'США']
# 8.67 ['Темный рыцарь', 'The Dark Knight', 2008, 8.505, 'триллер,боевик,драма,фантастика,криминал', 'Великобритания,США']
# 8.64 ['ВАЛЛ·И', 'WALL·E', 2008, 8.302999999999999, 'приключения,мультфильм,фантастика,семейный', 'США']
# 8.63 ['Американская история\xa0X', 'American History\xa0X', 1998, 8.298, 'драма,криминал', 'США']
# 8.61 ['Остров проклятых', 'Shutter Island', 2009, 8.492, 'драма,детектив,триллер', 'США']
# 8.59 ['Семь', 'Se7en', 1995, 8.296, 'драма,детектив,криминал,триллер', 'США']
# 8.56 ['Пробуждение', 'Awakenings', 1990, 8.443999999999999, 'драма,биография', 'США']
# 8.56 ['Тайна Коко', 'Coco', 2017, 8.639, 'музыка,семейный,фэнтези,приключения,мультфильм,детектив,комедия', 'США']
# 8.55 ['Терминатор 2: Судный день', 'Terminator 2: Judgment Day', 1991, 8.306000000000001, 'боевик,фантастика,триллер', 'Франция,США']
# 8.54 ['Пролетая над гнездом кукушки', "One Flew Over the Cuckoo's Nest", 1975, 8.552, 'драма', 'США']
# 8.53 ['Спасти рядового Райана', 'Saving Private Ryan', 1998, 8.179, 'драма,военный', 'США']
# 8.52 ['Храброе сердце', 'Braveheart', 1995, 8.283, 'драма,биография,история,военный', 'США']
# 8.52 ['Молчание ягнят', 'The Silence of the Lambs', 1990, 8.335, 'триллер,драма,ужасы,детектив,криминал', 'США']
# 8.5 ['Изгой', 'Cast Away', 2000, 8.253, 'драма,приключения,мелодрама', 'США']
# 8.5 ['Игра', 'The Game', 1997, 8.255, 'драма,приключения,детектив,триллер', 'США']
# Wall time: 1min 6s

# %%
# %%time

for rate, mid in get_reccomentations(user2vote_csr, n = 20, person_mid2vote=get_filmid2vote(votes_2), votes_count_thres = 100):
    print (round(rate, 2), get_movie_descr_by_id(mid))
# Out:
# 9.38 ['Побег из Шоушенка', 'The Shawshank Redemption', 1994, 9.112, 'драма', 'США']
# 9.34 ['Зеленая миля', 'The Green Mile', 1999, 9.062, 'драма,детектив,криминал,фэнтези', 'США']
# 9.21 ['Форрест Гамп', 'Forrest Gump', 1994, 8.916, 'драма,мелодрама', 'США']
# 9.13 ['Список Шиндлера', "Schindler's List", 1993, 8.818999999999997, 'драма,биография,история', 'США']
# 9.05 ['Король Лев', 'The Lion King', 1994, 8.773, 'семейный,драма,мюзикл,приключения,мультфильм', 'США']
# 9.01 ['1+1', 'Intouchables', 2011, 8.809, 'драма,биография,комедия', 'Франция']
# 8.95 ['Леон', 'Léon', 1994, 8.682, 'драма,криминал,триллер', 'Франция']
# 8.92 ['Начало', 'Inception', 2010, 8.665, 'боевик,драма,фантастика,детектив,триллер', 'Великобритания,США']
# 8.91 ['Властелин колец: Возвращение Короля', 'The Lord of the Rings: The Return of the King', 2003, 8.615, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 8.88 ['Назад в будущее', 'Back to the Future', 1985, 8.625, 'приключения,фантастика,комедия', 'США']
# 8.84 ['ВАЛЛ·И', 'WALL·E', 2008, 8.302999999999999, 'приключения,мультфильм,фантастика,семейный', 'США']
# 8.82 ['Властелин колец: Братство кольца', 'The Lord of the Rings: The Fellowship of the Ring', 2001, 8.562000000000001, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 8.81 ['Бойцовский клуб', 'Fight Club', 1999, 8.65, 'драма,криминал,триллер', 'Германия,США']
# 8.8 ['Пираты Карибского моря: Проклятие Черной жемчужины', 'Pirates of the Caribbean: The Curse of the Black Pearl', 2003, 8.337, 'боевик,приключения,фэнтези', 'США']
# 8.8 ['Титаник', 'Titanic', 1997, 8.369, 'драма,мелодрама', 'США']
# 8.79 ['Игры разума', 'A Beautiful Mind', 2001, 8.558, 'драма,биография,мелодрама', 'США']
# 8.79 ['Властелин колец: Две крепости', 'The Lord of the Rings: The Two Towers', 2002, 8.559, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 8.78 ['Престиж', 'The Prestige', 2006, 8.525, 'драма,детектив,фантастика,триллер', 'Великобритания,США']
# 8.78 ['Гладиатор', 'Gladiator', 2000, 8.587, 'боевик,драма,приключения', 'Великобритания,США']
# 8.77 ['Как приручить дракона', 'How to Train Your Dragon', 2010, 8.206, 'семейный,фэнтези,приключения,мультфильм,комедия', 'США']
# Wall time: 50.6 s

# %%
# %%time

for rate, mid in get_reccomentations(user2vote_csr, n = 20, person_mid2vote=get_filmid2vote(votes_3), votes_count_thres = 100):
    print (round(rate, 2), get_movie_descr_by_id(mid))
# Out:
# 9.26 ['Форрест Гамп', 'Forrest Gump', 1994, 8.916, 'драма,мелодрама', 'США']
# 9.16 ['Начало', 'Inception', 2010, 8.665, 'боевик,драма,фантастика,детектив,триллер', 'Великобритания,США']
# 9.05 ['Список Шиндлера', "Schindler's List", 1993, 8.818999999999997, 'драма,биография,история', 'США']
# 9.05 ['Властелин колец: Возвращение Короля', 'The Lord of the Rings: The Return of the King', 2003, 8.615, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 8.99 ['Матрица', 'The Matrix', 1999, 8.491, 'боевик,фантастика', 'США']
# 8.96 ['Бойцовский клуб', 'Fight Club', 1999, 8.65, 'драма,криминал,триллер', 'Германия,США']
# 8.93 ['Назад в будущее', 'Back to the Future', 1985, 8.625, 'приключения,фантастика,комедия', 'США']
# 8.93 ['Терминатор 2: Судный день', 'Terminator 2: Judgment Day', 1991, 8.306000000000001, 'боевик,фантастика,триллер', 'Франция,США']
# 8.92 ['Леон', 'Léon', 1994, 8.682, 'драма,криминал,триллер', 'Франция']
# 8.91 ['Король Лев', 'The Lion King', 1994, 8.773, 'семейный,драма,мюзикл,приключения,мультфильм', 'США']
# 8.91 ['Властелин колец: Братство кольца', 'The Lord of the Rings: The Fellowship of the Ring', 2001, 8.562000000000001, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 8.91 ['Интерстеллар', 'Interstellar', 2014, 8.586, 'драма,приключения,фантастика', 'Великобритания,США']
# 8.9 ['Престиж', 'The Prestige', 2006, 8.525, 'драма,детектив,фантастика,триллер', 'Великобритания,США']
# 8.89 ['Властелин колец: Две крепости', 'The Lord of the Rings: The Two Towers', 2002, 8.559, 'драма,приключения,фэнтези', 'Новая Зеландия,США']
# 8.87 ['Крестный отец', 'The Godfather', 1972, 8.735, 'драма,криминал', 'США']
# 8.86 ['1+1', 'Intouchables', 2011, 8.809, 'драма,биография,комедия', 'Франция']
# 8.86 ['Гладиатор', 'Gladiator', 2000, 8.587, 'боевик,драма,приключения', 'Великобритания,США']
# 8.85 ['Криминальное чтиво', 'Pulp Fiction', 1994, 8.62, 'криминал,триллер,комедия', 'США']
# 8.79 ['ВАЛЛ·И', 'WALL·E', 2008, 8.302999999999999, 'приключения,мультфильм,фантастика,семейный', 'США']
# 8.78 ['Пираты Карибского моря: Проклятие Черной жемчужины', 'Pirates of the Caribbean: The Curse of the Black Pearl', 2003, 8.337, 'боевик,приключения,фэнтези', 'США']
# Wall time: 55.3 s
